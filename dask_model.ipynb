# %%
import pandas as pd
import numpy as np
import dask.dataframe as dd
import pickle
from dask.diagnostics import ProgressBar
import xgboost as xgb
import dask_xgboost as dxgb
from sklearn.metrics import precision_score
from sklearn.metrics import confusion_matrix

# %%
import os
from dask.distributed import Client, progress
client = Client(os.environ.get("DISTRIBUTED_ADDRESS"))

# %%
pd.set_option('display.max_columns', 100)

# %%
df = pd.read_pickle('/appl/dirac/projects/attrsrch/greenfield/3quarter_cleaned.pkl')

# %%
# generate target0
df['target0'] = 0
df.loc[abs(df['prdw_appe'] - df['uad_appe']) <= 0.1, 'target0'] = 0
df.loc[df['prdw_appe'] - df['uad_appe'] > 0.1, 'target0'] = 1
df.loc[df['prdw_appe'] - df['uad_appe'] < -0.1, 'target0'] = 2

# %%
# generate target1
df['target1'] = 0
df.loc[abs(abs(df['prdw_ppe'] - df['market_prdw_ppe']) - abs(df['uad_ppe'] - df['market_uad_ppe'])) <= 0.1, 'target1'] = 0
df.loc[abs(df['prdw_ppe'] - df['market_prdw_ppe']) - abs(df['uad_ppe'] - df['market_uad_ppe']) > 0.1, 'target1'] = 1
df.loc[abs(df['prdw_ppe'] - df['market_prdw_ppe']) - abs(df['uad_ppe'] - df['market_uad_ppe']) < -0.1, 'target1'] = 2

# %%
# generate target2
df['target2'] = 0
df.loc[abs(abs(df['prdw_appe'] - abs(df['market_prdw_ppe'])) - abs(df['uad_appe'] - abs(df['market_uad_ppe']))) <= 0.1, 'target2'] = 0
df.loc[abs(df['prdw_appe'] - abs(df['market_prdw_ppe'])) - abs(df['uad_appe'] - abs(df['market_uad_ppe'])) > 0.1, 'target2'] = 1
df.loc[abs(df['prdw_appe'] - abs(df['market_prdw_ppe'])) - abs(df['uad_appe'] - abs(df['market_uad_ppe'])) < -0.1, 'target2'] = 2

# %%
# generate target3
df['target3'] = abs(df['prdw_appe'] - abs(df['market_prdw_ppe'])) - abs(df['uad_appe'] - abs(df['market_uad_ppe']))

# %%
df['year_diff'] = df['tax_year'] - df['uad_year']
df['yr_built_diff'] = df['yr_built_prdw'] - df['yr_built_uad']
df['age_diff'] = df['age_prdw'] - df['age_uad']
df['sf_diff'] = df['sf_prdw'] - df['sf_uad']
df['lot_diff'] = df['lot_prdw'] - df['lot_uad']
df['bath_diff'] = df['bath_prdw'] - df['bath_uad']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 522548 entries, 0 to 522547
# Data columns (total 71 columns):
# prop_id                     522548 non-null float32
# zip2                        522548 non-null object
# address2                    522548 non-null object
# state2                      522548 non-null object
# origval1                    522548 non-null float32
# origdte1                    522548 non-null datetime64[ns]
# refiflg1                    392551 non-null object
# tract_id                    522548 non-null object
# agency1                     522548 non-null object
# condo                       522548 non-null float32
# best_drve_vld_adr_typ_cd    522548 non-null object
# MSA                         522548 non-null float32
# MSANAME                     522548 non-null object
# CNTY                        522548 non-null float32
# uad                         522548 non-null float32
# prdw                        522548 non-null float32
# mtv                         439972 non-null float32
# avm                         522548 non-null float32
# mtv_n                       439972 non-null float32
# mtv_origval1                439972 non-null float32
# mtv_origval2                327890 non-null float32
# mtv_origdat1                439972 non-null datetime64[ns]
# mtv_origdat2                327890 non-null datetime64[ns]
# mtv_refi1                   322636 non-null object
# mtv_refi2                   226069 non-null object
# code_prdw                   522548 non-null object
# sf_prdw                     522548 non-null float32
# lot_prdw                    522548 non-null float32
# bath_prdw                   522548 non-null float32
# yr_built_prdw               522548 non-null float32
# rooms_prdw                  266788 non-null float32
# garage_prdw                 375833 non-null float32
# part_bath_prdw              165023 non-null float32
# bsmt_prdw                   2811 non-null float32
# tax_year                    522548 non-null float32
# age_prdw                    522548 non-null float32
# sf_uad                      522548 non-null float32
# bath_uad                    522548 non-null float32
# lot_uad                     522548 non-null float32
# bdrm_uad                    522548 non-null float32
# rooms_uad                   522548 non-null float32
# bsmt_uad                    522535 non-null float32
# bsmf_uad                    216198 non-null float32
# yr_built_uad                522548 non-null float32
# age_uad                     522548 non-null float32
# uad_bookdat                 522548 non-null datetime64[ns]
# garage_uad                  522544 non-null float32
# cond_uad                    522548 non-null float32
# qlty_uad                    522548 non-null float32
# lctn_uad                    522536 non-null float32
# vew_uad                     522535 non-null float32
# uad_year                    522548 non-null int64
# mkt_prdw                    522548 non-null object
# cnty                        522548 non-null float32
# mkt_uad                     522548 non-null object
# prdw_ppe                    522548 non-null float32
# uad_ppe                     522548 non-null float32
# prdw_appe                   522548 non-null float32
# uad_appe                    522548 non-null float32
# market_prdw_ppe             522548 non-null float32
# market_uad_ppe              522548 non-null float32
# target0                     522548 non-null int64
# target1                     522548 non-null int64
# target2                     522548 non-null int64
# target3                     522548 non-null float32
# year_diff                   522548 non-null float64
# yr_built_diff               522548 non-null float32
# age_diff                    522548 non-null float32
# sf_diff                     522548 non-null float32
# lot_diff                    522548 non-null float32
# bath_diff                   522548 non-null float32
# dtypes: datetime64[ns](4), float32(49), float64(1), int64(4), object(13)
# memory usage: 189.4+ MB

# %%
ddf = dd.from_pandas(df, npartitions=1).persist()
ddf.head()
# Out:
#      prop_id   zip2                address2 state2  origval1   origdte1  \
# 0  1783271.0  01001            108 RIVER RD     MA  230000.0 2018-07-31
# 1  1913909.0  01001  116 HUNTERS GREENE CIR     MA  371500.0 2018-08-31
# 2  1155968.0  01001            16 VERNON ST     MA  210000.0 2018-07-30
# 3  1783440.0  01001         24 STEVENSON LN     MA  458000.0 2018-08-10
# 4  1929405.0  01001          25 DEER RUN RD     MA  365000.0 2018-07-27
#
#   refiflg1     tract_id agency1  condo best_drve_vld_adr_typ_cd      MSA  \
# 0        N  25013813208      01    0.0                        1  44140.0
# 1        N  25013813205      10    0.0                        1  44140.0
# 2        N  25013813207      01    0.0                        1  44140.0
# 3        N  25013813209      02    0.0                        1  44140.0
# 4     None  25013813205      04    0.0                        1  44140.0
#
#            MSANAME     CNTY            uad           prdw            mtv  \
# 0  Springfield, MA  25013.0  229817.843750  227090.125000  218544.109375
# 1  Springfield, MA  25013.0  386818.281250  404168.375000  326432.781250
# 2  Springfield, MA  25013.0  192756.453125  204937.859375  177887.968750
# 3  Springfield, MA  25013.0  443239.031250  492219.000000  540173.937500
# 4  Springfield, MA  25013.0  314359.906250  352584.468750  374149.062500
#
#              avm  mtv_n  mtv_origval1  mtv_origval2 mtv_origdat1 mtv_origdat2  \
# 0  223958.671875    2.0      190000.0      224359.0   2015-05-26   2006-06-23
# 1  370189.750000    2.0      310000.0      243042.0   2012-02-28   2004-10-18
# 2  188299.828125    1.0      151000.0           NaN   2011-12-28          NaT
# 3  480115.625000    1.0      506950.0           NaN   2008-07-23          NaT
# 4  335040.937500    2.0      260000.0      189000.0   2002-09-06   1997-08-29
#
#   mtv_refi1 mtv_refi2 code_prdw  sf_prdw  lot_prdw  bath_prdw  yr_built_prdw  \
# 0         R         N  newchar4   1072.0   18971.0        1.0         1955.0
# 1      None         R  newchar4   2594.0   43369.0        2.0         1990.0
# 2      None      None  newchar4    960.0   17550.0        1.0         1960.0
# 3      None      None  newchar4   2955.0   25673.0        3.0         2008.0
# 4      None         N  newchar4   2088.0   21261.0        2.0         1989.0
#
#    rooms_prdw  garage_prdw  part_bath_prdw  bsmt_prdw  tax_year  age_prdw  \
# 0         5.0          NaN             1.0        NaN    2017.0      64.0
# 1         8.0          NaN             1.0        NaN    2017.0      29.0
# 2         4.0          NaN             NaN        NaN    2017.0      59.0
# 3         7.0          NaN             NaN        NaN    2017.0      11.0
# 4         6.0          NaN             1.0        NaN    2017.0      30.0
#
#    sf_uad  bath_uad       lot_uad  bdrm_uad  rooms_uad  bsmt_uad  bsmf_uad  \
# 0  1070.0       1.0  19166.400391       3.0        5.0    1070.0     860.0
# 1  2610.0       2.5  43560.000000       4.0        8.0    1490.0       0.0
# 2   960.0       1.0  17424.000000       2.0        4.0     960.0       0.0
# 3  2950.0       3.0  25700.400391       4.0        8.0    2080.0       0.0
# 4  1920.0       2.5  21344.400391       3.0        6.0    1150.0     810.0
#
#    yr_built_uad  age_uad uad_bookdat  garage_uad  cond_uad  qlty_uad  \
# 0        1955.0     64.0  2018-07-02         1.0       3.0       4.0
# 1        1990.0     29.0  2018-08-16         2.0       3.0       3.0
# 2        1960.0     59.0  2018-07-03         1.0       3.0       4.0
# 3        2008.0     11.0  2016-05-22         2.0       3.0       3.0
# 4        1989.0     30.0  2018-07-10         2.0       4.0       4.0
#
#    lctn_uad  vew_uad  uad_year mkt_prdw     cnty mkt_uad  prdw_ppe   uad_ppe  \
# 0       1.0      8.0      2018    25013  25013.0   25013 -0.012652 -0.000792
# 1       1.0      8.0      2018    25013  25013.0   25013  0.087936  0.041234
# 2       1.0      8.0      2018    25013  25013.0   25013 -0.024105 -0.082112
# 3       1.0      8.0      2016    25013  25013.0   25013  0.074714 -0.032229
# 4       1.0      8.0      2018    25013  25013.0   25013 -0.034015 -0.138740
#
#    prdw_appe  uad_appe  market_prdw_ppe  market_uad_ppe  target0  target1  \
# 0   0.012652  0.000792         0.005645         0.01895        0        0
# 1   0.087936  0.041234         0.005645         0.01895        0        0
# 2   0.024105  0.082112         0.005645         0.01895        0        0
# 3   0.074714  0.032229         0.005645         0.01895        0        0
# 4   0.034015  0.138740         0.005645         0.01895        2        2
#
#    target2   target3  year_diff  yr_built_diff  age_diff  sf_diff    lot_diff  \
# 0        0 -0.011151       -1.0            0.0       0.0      2.0 -195.400391
# 1        0  0.060008       -1.0            0.0       0.0    -16.0 -191.000000
# 2        0 -0.044701       -1.0            0.0       0.0      0.0  126.000000
# 3        0  0.055790        1.0            0.0       0.0      5.0  -27.400391
# 4        0 -0.091419       -1.0            0.0       0.0    168.0  -83.400391
#
#    bath_diff
# 0        0.0
# 1       -0.5
# 2        0.0
# 3        0.0
# 4       -0.5

# %%
# pick columns
cols = [
#         'tax_year', 
        'yr_built_prdw', 'sf_prdw', 'lot_prdw', 'bath_prdw', 
        'uad_year', 'yr_built_uad', 'sf_uad', 'lot_uad', 'bdrm_uad', 'bath_uad', 
#         'year_diff', 
        'yr_built_diff', 'sf_diff', 'lot_diff', 'bath_diff'
        ]

X = ddf[cols]
Y0= ddf['target0']
Y1 = ddf['target1']
Y2 = ddf['target2']
Y3 = ddf['target3']

# %%
X_train, X_test = ddf.random_split([0.7, 0.3], random_state=1234)
Y_train, Y_test = Y3.random_split([0.7, 0.3], random_state=1234)

# %%
param = {
    'max_depth': 12,  # the maximum depth of each tree
    'eta': 0.1,  # the training step for each iteration
    'gamma': 2,
    'verbosity': 0,  # logging mode - quiet
    'objective': 'reg:squarederror', 
    'nround': 500,
#     'eval_metric': 'mlogloss',
#     'num_class': 3
}  # the number of classes that exist in this datset
# n_round = 500

# %%
# evallist  = [(dtrain,'train'), (dtest,'test')]
bst = dxgb.train(client, param, X_train, Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-c0fb1adf2892> in <module>
#       1 # evallist  = [(dtrain,'train'), (dtest,'test')]
# ----> 2 bst = dxgb.train(client, param, X_train, Y_train)
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/dask_xgboost/core.py in train(client, params, data, labels, dmatrix_kwargs, **kwargs)
#     240     """
#     241     return client.sync(
# --> 242         _train, client, params, data, labels, dmatrix_kwargs, **kwargs
#     243     )
#     244
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     761         else:
#     762             return sync(
# --> 763                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     764             )
#     765
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     330             e.wait(10)
#     331     if error[0]:
# --> 332         six.reraise(*error[0])
#     333     else:
#     334         return result[0]
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     691             if value.__traceback__ is not tb:
#     692                 raise value.with_traceback(tb)
# --> 693             raise value
#     694         finally:
#     695             value = None
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/distributed/utils.py in f()
#     315             if callback_timeout is not None:
#     316                 future = gen.with_timeout(timedelta(seconds=callback_timeout), future)
# --> 317             result[0] = yield future
#     318         except Exception as exc:
#     319             error[0] = sys.exc_info()
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     740                     if exc_info is not None:
#     741                         try:
# --> 742                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     743                         finally:
#     744                             # Break up a reference to itself
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/dask_xgboost/core.py in _train(client, params, data, labels, dmatrix_kwargs, **kwargs)
#     202
#     203     # Get the results, only one will be non-None
# --> 204     results = yield client._gather(futures)
#     205     result = [v for v in results if v][0]
#     206     num_class = params.get("num_class")
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     733
#     734                     try:
# --> 735                         value = future.result()
#     736                     except Exception:
#     737                         exc_info = sys.exc_info()
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/tornado/gen.py in run(self)
#     740                     if exc_info is not None:
#     741                         try:
# --> 742                             yielded = self.gen.throw(*exc_info)  # type: ignore
#     743                         finally:
#     744                             # Break up a reference to itself
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1678                             exc = CancelledError(key)
#    1679                         else:
# -> 1680                             six.reraise(type(exception), exception, traceback)
#    1681                         raise exc
#    1682                     if errors == "skip":
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/distributed/protocol/pickle.py in loads()
#      59 def loads(x):
#      60     try:
# ---> 61         return pickle.loads(x)
#      62     except Exception:
#      63         logger.info("Failed to deserialize %s", x[:10000], exc_info=True)
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/dask_xgboost/__init__.py in <module>
# ----> 1 from .core import XGBClassifier, XGBRegressor, _train, predict, train  # noqa
#       2
#       3 __version__ = "0.1.9"
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/dask_xgboost/core.py in <module>
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 import xgboost as xgb
#      10 from dask import delayed
#      11 from dask.distributed import default_client, wait
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/xgboost/__init__.py in <module>
#       9 import os
#      10
# ---> 11 from .core import DMatrix, Booster
#      12 from .training import train, cv
#      13 from . import rabit                   # noqa
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/xgboost/core.py in <module>
#      20 import scipy.sparse
#      21
# ---> 22 from .compat import (STRING_TYPES, PY3, DataFrame, MultiIndex, py_str,
#      23                      PANDAS_INSTALLED, DataTable)
#      24 from .libpath import find_lib_path
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/xgboost/compat.py in <module>
#      49 # dt
#      50 try:
# ---> 51     import datatable
#      52     if hasattr(datatable, "Frame"):
#      53         DataTable = datatable.Frame
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/datatable/__init__.py in <module>
#      22 #-------------------------------------------------------------------------------
#      23 from .__version__ import version as __version__
# ---> 24 from .frame import Frame
#      25 from .expr import (mean, min, max, sd, isna, sum, count, first, abs, exp,
#      26                    log, log10, f, g, median)
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/datatable/frame.py in <module>
#      27
#      28 from datatable.lib import core
# ---> 29 from datatable.options import options
#      30
#      31 __all__ = ("Frame", )
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/datatable/options.py in <module>
#       7 from contextlib import contextmanager
#       8 from datatable.lib import core
# ----> 9 from datatable.utils.terminal import term
#      10 from datatable.utils.typechecks import TTypeError, TValueError, name_type
#      11
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/datatable/utils/terminal.py in <module>
#     180
#     181 # Instantiate a terminal
# --> 182 term = Terminal()
#     183
#     184
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/datatable/utils/terminal.py in __init__()
#      53                 pass
#      54
# ---> 55             self._blessed_term = blessed.Terminal()
#      56
#      57             # Restore previous locale settings
#
# /appl/dirac/envs/v8/.conda/envs/v8/lib/python3.6/site-packages/blessed/terminal.py in __init__()
#     174             stream = sys.__stdout__
#     175         if stream in (sys.__stdout__, sys.__stderr__):
# --> 176             self._keyboard_fd = sys.__stdin__.fileno()
#     177
#     178         # we assume our input stream to be line-buffered until either the
#
# ValueError: I/O operation on closed file
